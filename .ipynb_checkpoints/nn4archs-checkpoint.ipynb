# %% [markdown]
# # Model architectures for nn4 inception

# %%
from keras.models import load_model
# model = load_model('./model/nn4.small2.lrn.h5')
from keras.utils import CustomObjectScope
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # nn4.small2.lrn.h5

# %%
## nn4.small2.lrn.h5 ##

with CustomObjectScope({'tf': tf}):
    model = load_model('/home/coep/pkm/distillation/py3model/keras/nn4.small2.lrn.h5')
model.summary()
# Out:
# WARNING:tensorflow:From /home/coep/venv/py3-tflowcpu/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 102, 102, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_1[0][0]
# ...

# %% [markdown]
# # nn4.small2.v1.h5

# %%
### nn4.small2.v1.h5 ###

with CustomObjectScope({'tf': tf}):
    model = load_model('/home/coep/pkm/Keras-OpenFace/model/nn4.small2.v1.h5')
model.summary()
# Out:
# WARNING:tensorflow:From /home/coep/venv/py2-tflowcpu/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_6 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_97 (ZeroPadding2 (None, 102, 102, 3)  0           input_6[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_97[0][0]
# ...

# %% [markdown]
# # nn4.small2.v2.h5

# %%
### nn4.small2.v2.h5 ###

with CustomObjectScope({'tf': tf}):
    model = load_model('/home/coep/pkm/Keras-OpenFace/model/nn4.small2.v2.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 3, 96, 96)    0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 192, 12, 12)  125696      input_1[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv1 (Conv2D) (None, 96, 12, 12)   18528       sequential_1[1][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv1 (Conv2D) (None, 16, 12, 12)   3088        sequential_1[1][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn1 (BatchNorm (None, 96, 12, 12)   384         inception_3a_3x3_conv1[0][0]
# ...

# %% [markdown]
# # nn4.small2.norm.h5

# %%
### nn4.small2.norm.h5 ###

with CustomObjectScope({'tf': tf}):
    model = load_model('/home/coep/pkm/Keras-OpenFace/model/nn4.small2.norm.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_6 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_80 (ZeroPadding2 (None, 102, 102, 3)  0           input_6[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_80[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 48, 48, 64)   0           bn1[0][0]
# ...

# %% [markdown]
# # nn4.small2.no_lambda.h5

# %%
### nn4.small2.no_lambda.h5 ###

with CustomObjectScope({'tf': tf}):
    model = load_model('/home/coep/pkm/Keras-OpenFace/model/nn4.small2.no_lambda.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 3, 96, 96)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 3, 102, 102)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 48, 48)   9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 64, 48, 48)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 48, 48)   0           bn1[0][0]
# ...

# %% [markdown]
# # nn4.small2.lambdas.h5

# %%
### nn4.small2.lambdas.h5 ###

with CustomObjectScope({'tf': tf}):
    model = load_model('/home/coep/pkm/Keras-OpenFace/model/nn4.small2.lambdas.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 102, 102, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 64)   0           bn1[0][0]
# ...

# %% [markdown]
# # nn4.small2.channel_first.h5

# %%
### nn4.small2.channel_first.h5 ###

with CustomObjectScope({'tf': tf}):
    model = load_model('/home/coep/pkm/Keras-OpenFace/model/nn4.small2.channel_first.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_57 (ZeroPadding2 (None, 102, 102, 3)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_57[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 48, 48, 64)   0           bn1[0][0]
# ...

# %% [markdown]
# # End
